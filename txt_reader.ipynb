# %% [markdown]
# #Aquí utilizamos la with open para abrir el texto y empezar a trabajar con los datos TXT.

# %%
with open ("datos_nba.txt", "r", encoding = "utf-8") as archivo:
    lines = archivo.readlines()

# %%
print (lines[:5])
# Out:
# ['player,team,position,points,rebounds,assists,season\n', 'Nikola Jokic,Nuggets,C,25.8,12.1,8.9,2025-26\n', 'Luka Doncic,Mavericks,PG,32.6,8.9,9.4,2025-26\n', 'Giannis Antetokounmpo,Bucks,PF,29.7,11.3,6.1,2025-26\n', 'Shai Gilgeous-Alexander,Thunder,SG,30.2,5.6,6.4,2025-26\n']

# %% [markdown]
# #En este paso lo que hacemos es:
# 1. Sacar la cabecera del archivo. Lines (primera línea), strip (elimina el salto de línea) y split(separa por comas).
# 2. Con la varibale data sacamos toodas las líneas excepto la primera.

# %%
header = lines [0].strip().split(",")
data = lines[1:]
print (header)
print (lines)
# Out:
# ['player', 'team', 'position', 'points', 'rebounds', 'assists', 'season']
# ['player,team,position,points,rebounds,assists,season\n', 'Nikola Jokic,Nuggets,C,25.8,12.1,8.9,2025-26\n', 'Luka Doncic,Mavericks,PG,32.6,8.9,9.4,2025-26\n', 'Giannis Antetokounmpo,Bucks,PF,29.7,11.3,6.1,2025-26\n', 'Shai Gilgeous-Alexander,Thunder,SG,30.2,5.6,6.4,2025-26\n', 'Jayson Tatum,Celtics,SF,27.4,8.3,5.1,2025-26\n', 'Joel Embiid,76ers,C,31.8,10.7,4.9,2025-26\n', 'Anthony Edwards,Timberwolves,SG,27.1,5.8,4.9,2025-26\n', 'Kevin Durant,Suns,SF,26.5,6.4,4.8,2025-26\n', 'Stephen Curry,Warriors,PG,25.9,4.3,5.2,2025-26\n', 'Devin Booker,Suns,SG,28.0,4.7,6.6,2025-26\n', 'LeBron James,Lakers,SF,24.8,7.1,7.9,2025-26\n', 'Anthony Davis,Lakers,PF,25.1,12.4,3.2,2025-26\n', 'Damian Lillard,Bucks,PG,24.9,4.2,6.8,2025-26\n', 'Kawhi Leonard,Clippers,SF,22.8,6.0,3.4,2025-26\n', 'Paul George,Clippers,SG,21.9,5.1,3.8,2025-26\n', 'Jimmy Butler,Heat,SF,21.3,5.4,5.2,2025-26\n', 'Ja Morant,Grizzlies,PG,26.8,5.7,8.4,2025-26\n', 'Trae Young,Hawks,PG,27.5,3.1,11.2,2025-26\n', 'Domantas Sabonis,Kings,C,20.1,13.4,8.0,2025-26\n', 'Tyrese Haliburton,Pacers,PG,21.4,4.0,11.0,2025-26\n', 'Zion Williamson,Pelicans,PF,23.6,6.2,4.5,2025-26\n', 'Jaylen Brown,Celtics,SG,24.2,5.6,3.7,2025-26\n', 'Kyrie Irving,Mavericks,PG,26.1,5.1,5.4,2025-26\n', 'Brandon Ingram,Pelicans,SF,21.5,5.2,5.6,2025-26\n', ',\n', 'Bam Adebayo,Heat,C,20.0,10.6,4.1,2025-26\n', "De'Aaron Fox,Kings,PG,27.2,4.8,5.9,2025-26\n", 'Jrue Holiday,Celtics,PG,13.1,5.5,4.6,2025-26\n', 'Kristaps Porzingis,Celtics,C,21.0,,2.2,2025-26\n', 'Pascal Siakam,Pacers,PF,22.3,7.4,4.5,2025-26\n', 'Rudy Gobert,Timberwolves,C,14.6,13.1,1.3,2025-26\n']

# %% [markdown]
# ##Ahora vamos a hacer una limpieza de los datos.

# %%
rows = [] #Creamos una variable para las celdas, en este caso filas vacías.

for line in data: #Aquí hemos creado un bucle para que python filtre los datos y nos devuelva aquellos que son válidos en forma de lista. For reccorre solo datos, no cabecera.
    values = line.strip().split (",") #El valor es una línea separa por comas.
    if len (values) == len(header): #Si tras recorrer la cadena los valores coinciden con la cabecera se le añade una celda.
        rows.append(values) #Solo se añaden filas válidas.
print (rows)
# Out:
# [['Nikola Jokic', 'Nuggets', 'C', '25.8', '12.1', '8.9', '2025-26'], ['Luka Doncic', 'Mavericks', 'PG', '32.6', '8.9', '9.4', '2025-26'], ['Giannis Antetokounmpo', 'Bucks', 'PF', '29.7', '11.3', '6.1', '2025-26'], ['Shai Gilgeous-Alexander', 'Thunder', 'SG', '30.2', '5.6', '6.4', '2025-26'], ['Jayson Tatum', 'Celtics', 'SF', '27.4', '8.3', '5.1', '2025-26'], ['Joel Embiid', '76ers', 'C', '31.8', '10.7', '4.9', '2025-26'], ['Anthony Edwards', 'Timberwolves', 'SG', '27.1', '5.8', '4.9', '2025-26'], ['Kevin Durant', 'Suns', 'SF', '26.5', '6.4', '4.8', '2025-26'], ['Stephen Curry', 'Warriors', 'PG', '25.9', '4.3', '5.2', '2025-26'], ['Devin Booker', 'Suns', 'SG', '28.0', '4.7', '6.6', '2025-26'], ['LeBron James', 'Lakers', 'SF', '24.8', '7.1', '7.9', '2025-26'], ['Anthony Davis', 'Lakers', 'PF', '25.1', '12.4', '3.2', '2025-26'], ['Damian Lillard', 'Bucks', 'PG', '24.9', '4.2', '6.8', '2025-26'], ['Kawhi Leonard', 'Clippers', 'SF', '22.8', '6.0', '3.4', '2025-26'], ['Paul George', 'Clippers', 'SG', '21.9', '5.1', '3.8', '2025-26'], ['Jimmy Butler', 'Heat', 'SF', '21.3', '5.4', '5.2', '2025-26'], ['Ja Morant', 'Grizzlies', 'PG', '26.8', '5.7', '8.4', '2025-26'], ['Trae Young', 'Hawks', 'PG', '27.5', '3.1', '11.2', '2025-26'], ['Domantas Sabonis', 'Kings', 'C', '20.1', '13.4', '8.0', '2025-26'], ['Tyrese Haliburton', 'Pacers', 'PG', '21.4', '4.0', '11.0', '2025-26'], ['Zion Williamson', 'Pelicans', 'PF', '23.6', '6.2', '4.5', '2025-26'], ['Jaylen Brown', 'Celtics', 'SG', '24.2', '5.6', '3.7', '2025-26'], ['Kyrie Irving', 'Mavericks', 'PG', '26.1', '5.1', '5.4', '2025-26'], ['Brandon Ingram', 'Pelicans', 'SF', '21.5', '5.2', '5.6', '2025-26'], ['Bam Adebayo', 'Heat', 'C', '20.0', '10.6', '4.1', '2025-26'], ["De'Aaron Fox", 'Kings', 'PG', '27.2', '4.8', '5.9', '2025-26'], ['Jrue Holiday', 'Celtics', 'PG', '13.1', '5.5', '4.6', '2025-26'], ['Kristaps Porzingis', 'Celtics', 'C', '21.0', '', '2.2', '2025-26'], ['Pascal Siakam', 'Pacers', 'PF', '22.3', '7.4', '4.5', '2025-26'], ['Rudy Gobert', 'Timberwolves', 'C', '14.6', '13.1', '1.3', '2025-26']]

# %% [markdown]
# #Ahora vamos a convertir la información que tenemos en forma de lista en diccionarios para que los datos sean más accesibles.

# %%
records = [] #Esta lista vacía contendrá los registros finales.

for row in rows:
    record = dict(zip(header, row)) #Dict convierte la información de zip es un diccionario. Zip empareja header (cabecera) con row (celda).
    records.append(record)

print (records[:3])
# Out:
# [{'player': 'Nikola Jokic', 'team': 'Nuggets', 'position': 'C', 'points': '25.8', 'rebounds': '12.1', 'assists': '8.9', 'season': '2025-26'}, {'player': 'Luka Doncic', 'team': 'Mavericks', 'position': 'PG', 'points': '32.6', 'rebounds': '8.9', 'assists': '9.4', 'season': '2025-26'}, {'player': 'Giannis Antetokounmpo', 'team': 'Bucks', 'position': 'PF', 'points': '29.7', 'rebounds': '11.3', 'assists': '6.1', 'season': '2025-26'}]

# %%
numeric_fields = ["points", "rebounds", "assists"]

for record in records:
    for field in numeric_fields:
        value = record[field]

        # Si ya es número, no hacemos nada
        if isinstance(value, (int, float)):
            continue

        # Si es string vacío o solo espacios
        if value.strip() == "":
            record[field] = None
        else:
            try:
                record[field] = float(value)
            except ValueError:
                record[field] = None
print(records[:3])
print(type(records[0]["points"]))
# Out:
# [{'player': 'Nikola Jokic', 'team': 'Nuggets', 'position': 'C', 'points': 25.8, 'rebounds': 12.1, 'assists': 8.9, 'season': '2025-26'}, {'player': 'Luka Doncic', 'team': 'Mavericks', 'position': 'PG', 'points': 32.6, 'rebounds': 8.9, 'assists': 9.4, 'season': '2025-26'}, {'player': 'Giannis Antetokounmpo', 'team': 'Bucks', 'position': 'PF', 'points': 29.7, 'rebounds': 11.3, 'assists': 6.1, 'season': '2025-26'}]
# <class 'float'>

# %%
point_values = []

for records in records:
    if record ["points"] != None:
        point_values.append(records ["points"])
mean_points = sum(point_values) / len(point_values)
print (mean_points)
# Out:
# 24.506666666666668
